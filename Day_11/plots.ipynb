# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import dataset 
kashati = sns.load_dataset('titanic')
kashati
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashati.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
kashati.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
kashati.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
kashati.loc[:,['age','deck','embark_town']]
# Out:
#       age deck  embark_town
# 0    22.0  NaN  Southampton
# 1    38.0    C    Cherbourg
# 2    26.0  NaN  Southampton
# 3    35.0    C  Southampton
# 4    35.0  NaN  Southampton
# ..    ...  ...          ...
# 886  27.0  NaN  Southampton
# 887  19.0    B  Southampton
# 888   NaN  NaN  Southampton
# 889  26.0    C    Cherbourg
# 890  32.0  NaN   Queenstown
#
# [891 rows x 3 columns]

# %%
kashati.survived.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
sns.countplot(x="sex", hue="sex", data=kashati)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x="survived",hue="sex",data=kashati)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
#scatter plot
plt.scatter(data=kashati, x="survived", y="who", color="sex")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Abdul Hannan\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:4378, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4377 try:
# -> 4378     mcolors.to_rgba_array(kwcolor)
#    4379 except ValueError as err:
#
# File c:\Users\Abdul Hannan\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\colors.py:487, in to_rgba_array(c, alpha)
#     486 else:
# --> 487     rgba = np.array([to_rgba(cc) for cc in c])
#     489 if alpha is not None:
#
# File c:\Users\Abdul Hannan\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\colors.py:487, in <listcomp>(.0)
#     486 else:
# --> 487     rgba = np.array([to_rgba(cc) for cc in c])
#     489 if alpha is not None:
#
# ...

# %%
# scatter plot k liye hemsha dono numeric value honi chahiye mtlb(x axis and y axis)  aur dono hi apk pas numbers ho mtlb flot ya intger
# aur hue waly hisy may category honi chahiye
sns.scatterplot(data=kashati, x="fare", y="age", hue="pclass")
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.barplot(data=kashati, x="sex", y="fare", hue="pclass")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.pairplot(kashati)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
kashati.hist()
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
kashati.hist(bins=10)
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
kashati.hist(bins=10, figsize=(9,7), grid=False)
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
sns.boxplot(data=kashati, x="sex", y ="fare", hue="pclass")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.boxenplot(data=kashati, x= "sex", y="fare", hue="class")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
facetgrid = sns.FacetGrid(kashati, hue="survived", col="sex", 
                          margin_titles=True, palette={1: "seagreen",0:"grey"})
facetgrid.map(plt.scatter, "fare", "age", edgecolor="w").add_legend()

# %%
sns.stripplot(data=kashati, x="sex", y ="fare", hue="class")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
#heatmap
corr = kashati.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr)
plt.title("heat map of kashtai data")
# Out:
# C:\Users\Abdul Hannan\AppData\Local\Temp\ipykernel_10328\1876651825.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = kashati.corr()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 5
#       3 plt.figure(figsize=(10,10))
#       4 sns.heatmap(corr)
# ----> 5 plt.title("heat map of kashtai data")
#
# TypeError: 'str' object is not callable

# %%
sns.violinplot(data=kashati, x="sex", y ="fare", hue="class")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

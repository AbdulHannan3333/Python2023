# %%
pip install streamlit-pandas-profiling
# Out:
# Requirement already satisfied: streamlit-pandas-profiling in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (0.1.3)
# Requirement already satisfied: pandas-profiling in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit-pandas-profiling) (3.6.6)
# Requirement already satisfied: streamlit>=0.63 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit-pandas-profiling) (1.21.0)
# Requirement already satisfied: altair<5,>=3.2.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (4.2.2)
# Requirement already satisfied: blinker>=1.0.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (1.6.2)
# Requirement already satisfied: cachetools>=4.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (5.3.0)
# Requirement already satisfied: click>=7.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (8.1.3)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (6.4.1)
# Requirement already satisfied: numpy in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (1.23.5)
# Requirement already satisfied: packaging>=14.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (23.1)
# Requirement already satisfied: pandas<2,>=0.25 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (1.5.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (9.5.0)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (3.20.3)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (11.0.0)
# Requirement already satisfied: pympler>=0.9 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (1.0.1)
# Requirement already satisfied: python-dateutil in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (2.8.2)
# Requirement already satisfied: requests>=2.4 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (2.28.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (13.3.4)
# Requirement already satisfied: toml in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (0.10.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (4.5.0)
# Requirement already satisfied: tzlocal>=1.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (4.3)
# Requirement already satisfied: validators>=0.2 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (0.20.0)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (3.1.31)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (0.8.1b0)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (6.2)
# Requirement already satisfied: watchdog in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from streamlit>=0.63->streamlit-pandas-profiling) (3.0.0)
# Requirement already satisfied: ydata-profiling in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from pandas-profiling->streamlit-pandas-profiling) (4.1.2)
# Requirement already satisfied: entrypoints in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from altair<5,>=3.2.0->streamlit>=0.63->streamlit-pandas-profiling) (0.4)
# Requirement already satisfied: jinja2 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from altair<5,>=3.2.0->streamlit>=0.63->streamlit-pandas-profiling) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from altair<5,>=3.2.0->streamlit>=0.63->streamlit-pandas-profiling) (4.17.3)
# Requirement already satisfied: toolz in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from altair<5,>=3.2.0->streamlit>=0.63->streamlit-pandas-profiling) (0.12.0)
# Requirement already satisfied: colorama in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from click>=7.0->streamlit>=0.63->streamlit-pandas-profiling) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from gitpython!=3.1.19->streamlit>=0.63->streamlit-pandas-profiling) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from importlib-metadata>=1.4->streamlit>=0.63->streamlit-pandas-profiling) (3.15.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from pandas<2,>=0.25->streamlit>=0.63->streamlit-pandas-profiling) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from python-dateutil->streamlit>=0.63->streamlit-pandas-profiling) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit-pandas-profiling) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit-pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit-pandas-profiling) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit-pandas-profiling) (2022.12.7)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from rich>=10.11.0->streamlit>=0.63->streamlit-pandas-profiling) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from rich>=10.11.0->streamlit>=0.63->streamlit-pandas-profiling) (2.15.0)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from tzlocal>=1.1->streamlit>=0.63->streamlit-pandas-profiling) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from tzlocal>=1.1->streamlit>=0.63->streamlit-pandas-profiling) (2023.3)
# Requirement already satisfied: backports.zoneinfo in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from tzlocal>=1.1->streamlit>=0.63->streamlit-pandas-profiling) (0.2.1)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from validators>=0.2->streamlit>=0.63->streamlit-pandas-profiling) (5.1.1)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (1.9.3)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (3.6.3)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (1.10.7)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (6.0)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (0.7.5)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (0.12.3)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (4.64.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (0.12.2)
# Requirement already satisfied: multimethod<1.10,>=1.4 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (1.9.1)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (0.13.5)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (2.13.3)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (4.3.1)
# Requirement already satisfied: PyWavelets in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (1.4.1)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (3.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (0.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit>=0.63->streamlit-pandas-profiling) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from jinja2->altair<5,>=3.2.0->streamlit>=0.63->streamlit-pandas-profiling) (2.1.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit>=0.63->streamlit-pandas-profiling) (5.12.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit>=0.63->streamlit-pandas-profiling) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit>=0.63->streamlit-pandas-profiling) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit>=0.63->streamlit-pandas-profiling) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (3.0.9)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (1.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\abdul hannan\.conda\envs\streamlit\lib\site-packages (from statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling->streamlit-pandas-profiling) (0.5.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import streamlit as st
import pandas_profiling
import seaborn as sns

# %%
from streamlit_pandas_profiling import st_profile_report

# %%
df = sns.load_dataset('titanic')

# %%
pr = df.profile_report()

# %%
st_profile_report(pr) # streamlit k app k andar run kar dia
# Out:
# Summarize dataset:  93%|█████████▎| 38/41 [00:21<00:01,  1.80it/s, Detecting duplicates]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 st_profile_report(pr) # streamlit k app k andar run kar dia
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\streamlit_pandas_profiling\__init__.py:54, in st_profile_report(report, height, navbar, key)
#      51     report.config.html.full_width = config["style"]["full_width"]
#      53 with st.spinner("Generating profile report..."):
# ---> 54     _render_component(html=report.to_html(), height=height, key=key, default=None)
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\pandas_profiling\profile_report.py:420, in ProfileReport.to_html(self)
#     412 def to_html(self) -> str:
#     413     """Generate and return complete template as lengthy string
#     414         for using with frameworks.
#     415
#    (...)
#     418
#     419     """
# --> 420     return self.html
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\pandas_profiling\profile_report.py:231, in ProfileReport.html(self)
#     228 @property
#     229 def html(self) -> str:
#     230     if self._html is None:
# --> 231         self._html = self._render_html()
#     232     return self._html
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\pandas_profiling\profile_report.py:339, in ProfileReport._render_html(self)
#     336 def _render_html(self) -> str:
#     337     from pandas_profiling.report.presentation.flavours import HTMLReport
# --> 339     report = self.report
#     341     with tqdm(
#     342         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     343     ) as pbar:
#     344         html = HTMLReport(copy.deepcopy(report)).render(
#     345             nav=self.config.html.navbar_show,
#     346             offline=self.config.html.use_local_assets,
#    (...)
#     354             version=self.description_set["package"]["pandas_profiling_version"],
#     355         )
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\pandas_profiling\profile_report.py:225, in ProfileReport.report(self)
#     222 @property
#     223 def report(self) -> Root:
#     224     if self._report is None:
# --> 225         self._report = get_report_structure(self.config, self.description_set)
#     226     return self._report
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\pandas_profiling\profile_report.py:207, in ProfileReport.description_set(self)
#     204 @property
#     205 def description_set(self) -> Dict[str, Any]:
#     206     if self._description_set is None:
# --> 207         self._description_set = describe_df(
#     208             self.config,
#     209             self.df,
#     210             self.summarizer,
#     211             self.typeset,
#     212             self._sample,
#     213         )
#     214     return self._description_set
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\pandas_profiling\model\describe.py:146, in describe(config, df, summarizer, typeset, sample)
#     143 pbar.update()
#     145 # Duplicates
# --> 146 metrics, duplicates = progress(get_duplicates, pbar, "Detecting duplicates")(
#     147     config, df, supported_columns
#     148 )
#     149 table_stats.update(metrics)
#     151 alerts = progress(get_alerts, pbar, "Get alerts")(
#     152     config, table_stats, series_description, correlations
#     153 )
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\pandas_profiling\utils\progress_bar.py:11, in progress.<locals>.inner(*args, **kwargs)
#       8 @wraps(fn)
#       9 def inner(*args, **kwargs) -> Any:
#      10     bar.set_postfix_str(message)
# ---> 11     ret = fn(*args, **kwargs)
#      12     bar.update()
#      13     return ret
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\multimethod\__init__.py:315, in multimethod.__call__(self, *args, **kwargs)
#     313 func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 except TypeError as ex:
#     317     raise DispatchError(f"Function {func.__code__}") from ex
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\pandas_profiling\model\pandas\duplicates_pandas.py:37, in pandas_get_duplicates(config, df, supported_columns)
#      30     raise ValueError(
#      31         f"Duplicates key ({duplicates_key}) may not be part of the DataFrame. Either change the "
#      32         f" column name in the DataFrame or change the 'duplicates.key' parameter."
#      33     )
#      35 duplicated_rows = df.duplicated(subset=supported_columns, keep=False)
#      36 duplicated_rows = (
# ---> 37     df[duplicated_rows]
#      38     .groupby(supported_columns, dropna=False)
#      39     .size()
#      40     .reset_index(name=duplicates_key)
#      41 )
#      43 metrics["n_duplicates"] = len(duplicated_rows[duplicates_key])
#      44 metrics["p_duplicates"] = metrics["n_duplicates"] / len(df)
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\pandas\core\groupby\groupby.py:2433, in GroupBy.size(self)
#    2428 if not self.as_index:
#    2429     # error: Incompatible types in assignment (expression has
#    2430     # type "DataFrame", variable has type "Series")
#    2431     result = result.rename("size").reset_index()  # type: ignore[assignment]
# -> 2433 return self._reindex_output(result, fill_value=0)
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\pandas\core\groupby\groupby.py:4171, in GroupBy._reindex_output(self, output, fill_value, qs)
#    4169     levels_list.append(qs)  # type: ignore[arg-type]
#    4170     names = names + [None]
# -> 4171 index, _ = MultiIndex.from_product(levels_list, names=names).sortlevel()
#    4173 if self.as_index:
#    4174     # Always holds for SeriesGroupBy unless GH#36507 is implemented
#    4175     d = {
#    4176         self.obj._get_axis_name(self.axis): index,
#    4177         "copy": False,
#    4178         "fill_value": fill_value,
#    4179     }
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\pandas\core\indexes\multi.py:643, in MultiIndex.from_product(cls, iterables, sortorder, names)
#     640     names = [getattr(it, "name", None) for it in iterables]
#     642 # codes are all ndarrays, so cartesian_product is lossless
# --> 643 codes = cartesian_product(codes)
#     644 return cls(levels, codes, sortorder=sortorder, names=names)
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\pandas\core\reshape\util.py:60, in cartesian_product(X)
#      56     b = np.zeros_like(cumprodX)
#      58 # error: Argument of type "int_" cannot be assigned to parameter "num" of
#      59 # type "int" in function "tile_compat"
# ---> 60 return [
#      61     tile_compat(
#      62         np.repeat(x, b[i]),
#      63         np.product(a[i]),  # pyright: ignore[reportGeneralTypeIssues]
#      64     )
#      65     for i, x in enumerate(X)
#      66 ]
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\pandas\core\reshape\util.py:62, in <listcomp>(.0)
#      56     b = np.zeros_like(cumprodX)
#      58 # error: Argument of type "int_" cannot be assigned to parameter "num" of
#      59 # type "int" in function "tile_compat"
#      60 return [
#      61     tile_compat(
# ---> 62         np.repeat(x, b[i]),
#      63         np.product(a[i]),  # pyright: ignore[reportGeneralTypeIssues]
#      64     )
#      65     for i, x in enumerate(X)
#      66 ]
#
# File <__array_function__ internals>:180, in repeat(*args, **kwargs)
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\numpy\core\fromnumeric.py:479, in repeat(a, repeats, axis)
#     436 @array_function_dispatch(_repeat_dispatcher)
#     437 def repeat(a, repeats, axis=None):
#     438     """
#     439     Repeat elements of an array.
#     440
#    (...)
#     477
#     478     """
# --> 479     return _wrapfunc(a, 'repeat', repeats, axis=axis)
#
# File c:\Users\Abdul Hannan\.conda\envs\streamlit\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# MemoryError: Unable to allocate 497. MiB for an array with shape (520914240,) and data type int8
